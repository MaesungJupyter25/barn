# %% [markdown]
# # 주피터에 오신것을 환영합니다.
# 저흰 소위 온라인 주피터(jupyter notebook이라는 파이썬 실행 환경)인 구글 코랩을 이용해 활동해보려 합니다
#
# 프로그래밍 경쟁 식으로 진행되는데요, 일단 코랩과 파이썬에 익숙해지는 시간부터 가지겠습니다.
#
# 1학년때 파이썬을 배우긴 했으니 진도는 프로그래밍의 꽃인 함수부터 시작합니다.
#
# 모르겠으면 질문하던 검색하던 ㄱㄱ

# %%
# 코랩(주피터)는 코드를 적고, 그걸 왼쪽의 실행 버튼을 눌러 개별적으로 실행할 수 있습니다
# 왼쪽 버튼을 눌러 밑 코드를 실행해 보세요
# 해시태그(#) 뒤에 쓰이는 초록색 글은 주석입니다. 실행되지 않음.
print("hello colab!")
print("대부분의 코드는 꼭 순서대로 실행하기.")
# Out:
# hello colab!
# 대부분의 코드는 꼭 순서대로 실행하기.

# %%
# 이건 해당 코랩 파일의 기초적인 종속성을 불러오는 코드입니다.
# 그냥 실행 한번 시켜주세요.
# 다른 코랩 파일에도 여럿 볼 수 있을겁니다. 적당히 눈치채고 실행시키세요.

import numpy as np
import matplotlib.pyplot as plt

print("종속성 불러오기 완료")

# 이것또한 마찬가지
def draw_func(func):
  x = np.arange(1, 100, 0.05)
  y = [func(x) for x in x]
  plt.plot(x, y)

print("기능 불러오기 완료")
# Out:
# 종속성 불러오기 완료
# 기능 불러오기 완료

# %%
# 간단한 1차함수로 시작하겠습니다
# f(x) = x + 1

def linear(x):
  return
  # x를 받아 x+1을 반환하는 코드


# 함수 결과를 차례대로 출력합니다
print(linear(2))
print(linear(3))
print(linear(10))
print(linear(999))
# Out:
# 4
# 9
# 100
# 998001

# %% [markdown]
# 특정한 함수를 그래프로 그리고 싶다면 draw_func([함수이름]) 을 사용해 주세요.
#
# ex) 내 함수 이름이 my_func(x) 라면,
#
# draw_func(my_func)

# %%
draw_func(linear)

# %% [markdown]
# 그래프의 정의역, 치역 설정은 추후 서술합니다.

# %% [markdown]
# 이제 직접 코드를 짜게 됩니다.
#
# ```
# # ~ ~ ~
# ```
#
# 로 감싸져 있거나,
#
# ```
# pass
# ```
#
# 아무것도 하지 않는 코드인 pass 부분은 직접 수정해 프로그래밍을 완성해 보세요.

# %%
def quadratic(x):
  # ~~~ 아무 이차함수를 만들어 보세요.
  return
  # ~~~

  # None을 지우고 적절한 코드를 넣으세요.
  # 힌트: 제곱은 ** 입니다.  2^7 -> 2 ** 7

# %%
# 확인해 보기
draw_func(quadratic)

# %% [markdown]
# 검증 코드는 귀찮으니 안만들겠습니다
#
# 대충 함수를 알게되었으니 이제 간단한 테스트를 몇개 해보죠
#
# 아래는 앞으로 동아리에서 할 '경쟁적 코딩' 의 맛보기 느낌입니다

# %%
# 문제 1
# x < 50 에서는 100을, 이상에서는 2x를 반환하는 함수
def f(x):
  return 100 if x < 50 else 2 * x *

# %%
# 확인하기
draw_func(f)

# %%
# a, b가 주어지면, a+b, a-b, a*b, a/b를 출력하는 코드
def f(a, b):
  print()
  print()
  print()
  print()

# %%
# 확인
print("test 1")
f(10, 5)
print("test 2")
f(20, 10)
print("test 3")
f(1, 3)
# Out:
# test 1
#
#
#
#
# test 2
#
#
#
#
# test 3
