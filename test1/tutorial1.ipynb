# %% [markdown]
# # 주피터에 오신것을 환영합니다.
# 저흰 소위 온라인 주피터(jupyter notebook이라는 파이썬 실행 환경)인 구글 코랩을 이용해 활동해보려 합니다
#
# 프로그래밍 경쟁 식으로 진행되는데요, 일단 코랩과 파이썬에 익숙해지는 시간부터 가지겠습니다.
#
# 1학년때 파이썬을 배우긴 했으니 진도는 프로그래밍의 꽃인 함수부터 시작합니다.
#
# 모르겠으면 질문하던 검색하던 ㄱㄱ
#
# 수정하다 보니 말투가 비일관적인 찐빠가 있지만 알아서 읽도록.

# %%
# 코랩(주피터)는 코드를 적고, 그걸 왼쪽의 실행 버튼을 눌러 개별적으로 실행할 수 있습니다
# 왼쪽 버튼을 눌러 밑 코드를 실행해 보세요
# 해시태그(#) 뒤에 쓰이는 초록색 글은 주석입니다. 실행되지 않음.
print("hello colab!")
print("대부분의 코드는 꼭 순서대로 실행하기.")
# Out:
# hello colab!
# 대부분의 코드는 꼭 순서대로 실행하기.

# %%
# 이건 해당 코랩 파일의 기초적인 종속성을 불러오는 코드입니다.
# 그냥 실행 한번 시켜주세요.
# 다른 코랩 파일에도 여럿 볼 수 있을겁니다. 적당히 눈치채고 실행시키세요.

import numpy as np
import matplotlib.pyplot as plt

print("종속성 불러오기 완료")

# 이것또한 마찬가지
def draw_func(func):
  x = np.arange(1, 100, 0.05)
  y = [func(x) for x in x]
  plt.plot(x, y)

print("기능 불러오기 완료")
# Out:
# 종속성 불러오기 완료
# 기능 불러오기 완료

# %% [markdown]
# 이제부터 직접 코드를 짜게 됩니다.
#
# ```
# return None
# ```
#
# None을 return하거나,
#
# ```
# pass
# ```
#
# 아무것도 하지 않는 코드인 pass 가 적혀있는 부분 등
#
# 작성해야 할 것으로 보이는 부분은 직접 수정 혹은 작성해 코드를 완성해 보세요.

# %%
# 간단한 1차함수로 시작하겠습니다
# f(x) = x + 1

def linear(x):
  return None
  # 여기를 수정해 보세요!
  # x를 받아 x+1을 반환하는 코드


# 함수 결과를 차례대로 출력합니다
print(linear(2))
print(linear(3))
print(linear(10))
print(linear(999))
# Out:
# None
# None
# None
# None

# %% [markdown]
# 특정한 함수를 그래프로 그리고 싶다면 draw_func([함수이름]) 을 사용해 주세요.
#
# ex) 내 함수 이름이 my_func(x) 라면,
#
# draw_func(my_func)

# %%
draw_func(linear)

# %% [markdown]
# 그래프의 정의역, 치역 설정은 추후 서술합니다. 일단은 잊어먹으세요.

# %%
def quadratic(x):
  # 아무 이차함수를 만들어 보세요.
  return None

  # None을 지우고 적절한 코드를 넣으세요.
  # 힌트: 제곱은 ** 입니다.  2^7 -> 2 ** 7

# %%
# 확인해 보기
draw_func(quadratic)

# %% [markdown]
# 검증 코드는 귀찮으니 안만들겠습니다
#
# 대충 함수를 알게되었으니 이제 간단한 테스트를 몇개 해보죠
#
# 아래는 앞으로 동아리에서 할 '경쟁적 코딩' 의 맛보기 느낌입니다

# %% [markdown]
# **풀다가 영 모르겠으면 질문하던 검색하던 해도 좋습니다.**
#
# 물론, 스스로 푸려는 의지도 높게 삽니다.
#
# 알 잘 딱 하 십 시 오 !

# %%
# 문제 1
# x < 50 에서는 100을, 이상에서는 2x를 반환하는 함수
def f(x):
  return None

# %%
# 확인하기
draw_func(f)

# %%
# 문제 2
# a, b가 주어지면, a+b, a-b, a*b, a/b를 출력하는 코드
# print() 의 괄호 안을 적절히 채워 보세요.
def f(a, b):
  print()
  print()
  print()
  print()

# %%
# 확인
print("test 1")
f(10, 5)
print("test 2")
f(20, 10)
print("test 3")
f(1, 3)
# Out:
# test 1
#
#
#
#
# test 2
#
#
#
#
# test 3

# %% [markdown]
# 어디서 본 것 같은 쉬운 문제죠?
#
# 좀 더 난이도를 높여봅시다.

# %%
# 문제 2-1
# 주어진 수 x를 받으면 그 수가 자연수의 제곱인지 확인하는 코드
# 구현하는 방법은 셀 수 없이 많습니다. 아예 시작부터 감이 안온다면 비슷한 예제를 검색해보는 능력을 길러봅니다.
def is_square_of_nn(x):
  return None

# %%
# 확인
for x in range(1, 20):
  print(f"{x}은(는) 자연수의 제곱인가? - {is_square_of_nn(x)}")
# Out:
# 1은(는) 자연수의 제곱인가? - None
# 2은(는) 자연수의 제곱인가? - None
# 3은(는) 자연수의 제곱인가? - None
# 4은(는) 자연수의 제곱인가? - None
# 5은(는) 자연수의 제곱인가? - None
# 6은(는) 자연수의 제곱인가? - None
# 7은(는) 자연수의 제곱인가? - None
# 8은(는) 자연수의 제곱인가? - None
# 9은(는) 자연수의 제곱인가? - None
# 10은(는) 자연수의 제곱인가? - None
# 11은(는) 자연수의 제곱인가? - None
# 12은(는) 자연수의 제곱인가? - None
# 13은(는) 자연수의 제곱인가? - None
# 14은(는) 자연수의 제곱인가? - None
# 15은(는) 자연수의 제곱인가? - None
# 16은(는) 자연수의 제곱인가? - None
# 17은(는) 자연수의 제곱인가? - None
# 18은(는) 자연수의 제곱인가? - None
# 19은(는) 자연수의 제곱인가? - None

# %% [markdown]
# 1, 4, 9, 16 에서 true, 나머지가 false 라면 옳겠죠?

# %%
# 이제 이전 코드를 응용한 심화 문제.
# 문제 2-2, 주어진 수 a, b가 있을 때, a부터 b까지 '자연수의 제곱인' 수가 몇 개 있는지 확인하는 코드를 작성해 보세요.
# 예시- a=5, b=16 이라면 5와 16 사이엔 9와 16이 있기에 2를 반환하는 것이 답입니다.

# 위에서 만든 is_square_of_nn 함수를 이용하거나 수정해도 좋습니다. (수정 후 적용하려면 해당 셀(칸) 왼쪽 실행 버튼을 누르세요.)

# 힌트: for문을 사용하세요.

# 단, 1 <= a < b <= 1000
def how_many_sonn(a, b): # sonn = square of natural numbers
  return None

# %%
# 테스트 케이스 1
how_many_sonn(1, 30)

# %%
# 테스트 케이스 2
how_many_sonn(64, 64)

# %%
# 테스트 케이스 3
how_many_sonn(1, 10000)

# %% [markdown]
# (여담으로 코랩에선 print를 꼭 적지 않더라도 셀의 마지막 함수 반환 결과를 자동 출력해 줍니다.)

# %% [markdown]
# 답이 출력되지 않고 멈춥니까?
#
# 오류가 아니라, 그냥 시간이 오지게 오래 걸리는 것입니다.
#
# 하나의 숫자 검사당 몇 번의 계산이 필요할지 얼추 계산해 보세요.

# %% [markdown]
# 테스트 케이스 1, 2는 쉽게 통과했을것이라 믿습니다.
#
# 하지만 3은 어떻게 할 수 있겠습니까??

# %% [markdown]
# 이처럼 문제를 해결하고 문제를 파악하며, 더 정확히, 더 빠른 시간에 작동하는 프로그램을 구상하고 실체화 해내는 능력을 시험하는 것이
#
# 이 '경쟁적 프로그래밍' 입니다. (테스트 케이스 3을 이미 해결했다면 축하합니다.)

# %% [markdown]
# 해당 동아리의 초기 몇 번은 이런 대수적이거나 다른 알고리즘적인 것을 먼저 다루고, 조금 익숙해졌을 때 쯤, 인공지능 이론들도 다루어 보겠습니다.
#
# 대수/알고리즘적 문제들은 문제 해결, 시간이 경쟁 요소지만
#
# 인공지능 쪽에선 데이터 분석, 그 모델의 정확성 등을 경쟁 요소로 둡니다.

# %%
# 만약 케이스 3을 빠르게 해결하고 싶다면, 조금의 힌트를 주겠습니다.
# 힌트가 좀 세니까 좀 더 생각해 보고 싶다면 충분히 생각 후 눌러보십시오.

# 여담으로 더블클릭을 빨리 하면 코드 수정이 열려서 스포되니 조심하세요 ..

# %% [markdown]
# <details>
# <summary>힌트 1</summary>
#
# 특정 숫자가 자연수의 제곱인지 확인하는 것보다, 거꾸로 생각해 어떤 수가 자연수의 제곱인지 골라내 보는건 어떻겠습니까?
#
# </details>
#
# <details>
# <summary>힌트 2</summary>
#
# '에라토스테네스의 체' 에 대해 알고 있습니까?
#
# </details>
#
# <details>
# <summary>힌트 3</summary>
#
# 매우 큰 배열을 이용해 보십시오.
#
# </details>

# %% [markdown]
# 잘 해결했습니까? 안 하고 왔더라도 괜찮습니다.
#
# 바로 다음 문제로 갑니다. 이제부터 조금 더 프로그래밍적인(더 적절한 단어가 생각 안남) 문제를 다룹니다.

# %%
# 문제 3 - 팩토리얼
# 주어진 수 x에 대해 x! 를 반환하세요.
def factorial(x):
  return None

# %%
factorial(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-3fd9b1939623> in <cell line: 0>()
# ----> 1 factorial(3)
#
# NameError: name 'factorial' is not defined

# %%
factorial(0)

# %%
factorial(9)

# %%
factorial(10)

# %%
# 문제 4 - 피보나치 수열
# 수 x가 주어졌을때, 피보나치 수열의 x번째 수를 반환해 보세요.
# 피보나치 수열을 모른다면 검색하세요..
def fibonacci(x):
  return None

# %%
fibonacci(5)

# %%
fibonacci(1)

# %%
fibonacci(15)

# %% [markdown]
# 또 코드가 멈추셨습니까?
#
# 이것 또한 왜 시간이 오래 걸리는지 직접 생각해보며 파악하고, 해결 방법을 생각해 봅시다.

# %% [markdown]
# 수고하셨습니다.
#
# 엥 벌써? 하는 사람도 있겠지만
#
# 오늘이 첫 시간이다보니 얼마나 따라오는지도 모르겠고, 쌤들이 자습 주라고 할지도 모르겠으니 일단 간만 보겠습니다...
#
# 더 뭐 하고싶다면 방장에게 말하십시오 할 거 있긴함 ㅋㅋ
